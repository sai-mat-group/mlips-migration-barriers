# %% [markdown]
# # Geometry Analysis

# %%
import os
import numpy as np
import itertools
import csv
from pymatgen.core import Structure
from pymatgen.analysis.local_env import VoronoiNN

# Define structure paths
#all_structures_path = {
 # 'CoF3_Co':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Perovskites/Co/CoF3',
#'Ca0.5MnF3':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Perovskites/Mn/Ca0.5MnF3',
#'Ca0.5NiF3':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Perovskites/Ni/Ca0.5NiF3',
#'NiF3':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Perovskites/Ni/NiF3',
#'Ca0.5VF3':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Perovskites/V/Ca0.5VF3',
#'CoF3_V':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Perovskites/V/CoF3',
#'Ca1.5Cr2F7_path1':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Cr/Ca1.5Cr2F7/path1',
#'Ca1.5Cr2F7_path2':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Cr/Ca1.5Cr2F7/path2',
#'Ca1.5Cr2F7_path3':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Cr/Ca1.5Cr2F7/path3',
#'Cr2F7_path1':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Cr/Cr2F7/path1',
#'Cr2F7_path3':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Cr/Cr2F7/path3',
#'Ca1.5Mn2F7_path1':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Mn/Ca1.5Mn2F7/path1',
#'Ca1.5Mn2F7_path2':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Mn/Ca1.5Mn2F7/path2',
#'Ca1.5Mn2F7_path3':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Mn/Ca1.5Mn2F7/path3',
#'Mn2F7_path1':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Mn/Mn2F7/path1',
#'Mn2F7_path2':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Mn/Mn2F7/path2',
#'Mn2F7_path3':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Mn/Mn2F7/path3',
#'Ca1.5Ni2F7_path1':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Ni/Ca1.5Ni2F7/path1',
#'Ca1.5Ni2F7_path2':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Ni/Ca1.5Ni2F7/path2',
#'Ca1.5Ni2F7_path3':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Ni/Ca1.5Ni2F7/path3',
#'Ni2F7_path1':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Ni/Ni2F7/path1',
#'Ni2F7_path2':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Ni/Ni2F7/path2',
#'Ni2F7_path3':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Ni/Ni2F7/path3',
#'Ca1.5Ti2F7_path1':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Ti/Ca1.5Ti2F7/path1',
#'Ca1.5Ti2F7_path2':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Ti/Ca1.5Ti2F7/path2',
#'Ca1.5Ti2F7_path3':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Ti/Ca1.5Ti2F7/path3',
#'Ti2F7_path1':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Ti/Ti2F7/path1',
#'Ti2F7_path2':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Ti/Ti2F7/path2',
#'Ti2F7_path3':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/Ti/Ti2F7/path3',
#'Ca1.5V2F7_path1':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/V/Ca1.5V2F7/path1',
#'Ca1.5V2F7_path2':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/V/Ca1.5V2F7/path2',
#'V2F7_path1':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/V/V2F7/path1',
#'V2F7_path2':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Weberites/V/V2F7/path2'
#}
#all_structures_path = {'santosh_data':'/Users/achinthyakrishna07/Downloads/migration_barrier/santosh_data'}
#all_structures_path = {
 #   'P2S_path2': '/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Ca_NaSICON_dereje_ORIGINAL/P2S/path2',
  #  'P2S_path3': '/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Ca_NaSICON_dereje_ORIGINAL/P2S/path3',
   # 'P2Si_path1': '/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Ca_NaSICON_dereje_ORIGINAL/P2Si',
   # 'PS2_path1': '/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Ca_NaSICON_dereje_ORIGINAL/PS2/path1',
    #'PS2_path2': '/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Ca_NaSICON_dereje_ORIGINAL/PS2/path2',
    #'PS2_path3': '/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Ca_NaSICON_dereje_ORIGINAL/PS2/path3',
    #'PSi2_path1': '/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Ca_NaSICON_dereje_ORIGINAL/PSi2/path1',
    #'PSi2_path2': '/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Ca_NaSICON_dereje_ORIGINAL/PSi2/path2',
    #'PSi2_path3': '/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Ca_NaSICON_dereje_ORIGINAL/PSi2/path3'
    
#}

#all_structures_path ={
 #   'Fe2S3O12':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Dereje_NaSICON/CaxFe2S3O12/Fe2S3O12',
 #   'Ca0.5Mn2P3O12':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Dereje_NaSICON/CaxMn2P3O12/Ca0.5Mn2P3O12',
 #   'Ca2.5Mn2P3O12':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Dereje_NaSICON/CaxMn2P3O12/Ca2.5Mn2P3O12',
  #  'CaMn2S3O12':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Dereje_NaSICON/CaxMn2S3O12/CaMn2S3O12',
  #  'Mn2S3O12':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Dereje_NaSICON/CaxMn2S3O12/Mn2S3O12',
  #  'Ca0.5V2P3O12':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Dereje_NaSICON/CaxV2P3O12/Ca0.5V2P3O12',
  #  'Ca2.5V2P3O12':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/Dereje_NaSICON/CaxV2P3O12/Ca2.5V2P3O12'
    
#}

all_structures_path ={
'LiCoO2_1':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/LiCoO2_1',
'LiCoO2_2':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/LiCoO2_2',
    'Mg0.148Ti2S4':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/Mg0.148Ti2S4',
    'MgMn2O4_I41amd':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/MgMn2O4_I41amd',
    'MgSc2Se4':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/MgSc2Se4',
    'Na3PS4':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/Na3PS4',
    'NaV2O4': '/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/NaV2O4',
    'O-LiFePO4': '/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/O-LiFePO4',
    'g-Li3PO4_1':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/g-Li3PO4_1',
    'g-Li3PO4_2':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/g-Li3PO4_2',
    'g-Li3PO4_9':'/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/g-Li3PO4_9'
}

def find_nearest_neighbors(structure):
    """Finds the 6 nearest neighbors to the 0th atom in a structure."""
    vnn = VoronoiNN()
    neighbors = vnn.get_nn_info(structure, 0)
    neighbor_list = [(neighbor['site_index'], neighbor['site'].coords, neighbor['poly_info']['solid_angle'])
                     for neighbor in neighbors]
    return sorted(neighbor_list, key=lambda x: structure[0].distance(structure[x[0]]))[:6]

def compute_relevant_distances(structure_file):
    """Computes distances for the 6 nearest neighbors of the 0th atom."""
    structure = Structure.from_file(structure_file)
    nearest_neighbors = find_nearest_neighbors(structure)
    print(nearest_neighbors)
    indices = [index for index, _, _ in nearest_neighbors]
    atom_distances = {(0, index): structure[0].distance(structure[index]) for index in indices}
    pairwise_distances = {(i, j): structure[i].distance(structure[j]) for i, j in itertools.combinations(indices, 2)}
    return {**atom_distances, **pairwise_distances}

def compute_solid_angles(structure_file):
    """Computes the solid angles of Voronoi faces for the 6 nearest neighbors."""
    structure = Structure.from_file(structure_file)
    nearest_neighbors = find_nearest_neighbors(structure)
    return {index: solid_angle for index, _, solid_angle in nearest_neighbors}

def compute_all_differences(structure_file_1, structure_file_2):
    """Computes differences in distances and solid angles between two structures."""
    distances_1, distances_2 = compute_relevant_distances(structure_file_1), compute_relevant_distances(structure_file_2)
    solid_angles_1, solid_angles_2 = compute_solid_angles(structure_file_1), compute_solid_angles(structure_file_2)
    
    distance_differences = [abs(distances_1[p] - distances_2[p]) for p in distances_1 if p in distances_2]
    solid_angle_differences = [abs(solid_angles_1[i] - solid_angles_2[i]) for i in solid_angles_1 if i in solid_angles_2]
    
    return {
        "Mean Distance Difference (Å)": np.mean(distance_differences) if distance_differences else 0,
        "Max Distance Difference (Å)": max(distance_differences) if distance_differences else 0,
        "Mean Solid Angle Difference (sr)": np.mean(solid_angle_differences) if solid_angle_differences else 0,
        "Max Solid Angle Difference (sr)": max(solid_angle_differences) if solid_angle_differences else 0
    }

# CSV Output File
output_csv = "/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/structure_analysis_M3GNnet_run.csv"

with open(output_csv, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Structure", "Index", "Mean Distance Difference (Å)", "Max Distance Difference (Å)",
                     "Mean Solid Angle Difference (sr)", "Max Solid Angle Difference (sr)"])
    
    for structure_name, base_path in all_structures_path.items():
        for j in range(1, 8):
            dft_structure_path = os.path.join(base_path, f"0{j}/CONTCAR")
            mlip_structure_path = os.path.join(base_path, f"M3GNnet_run/neb_optimized_{j}.vasp")
            
            if os.path.exists(dft_structure_path) and os.path.exists(mace_structure_path):
                results = compute_all_differences(dft_structure_path, mace_structure_path)
                writer.writerow([structure_name, j, results["Mean Distance Difference (Å)"], results["Max Distance Difference (Å)"],
                                 results["Mean Solid Angle Difference (sr)"], results["Max Solid Angle Difference (sr)"]])
                print(f"Processed {structure_name}, Index {j}")
            else:
                print(f"Skipping {structure_name}, Index {j} (Missing Files)")

print(f"\n✅ Results saved to {output_csv}")
# Out:
# [(37, array([4.25384232, 4.30915966, 5.54655225]), 2.3239132108946166), (62, array([4.93689927, 2.99160712, 8.44012494]), 2.2761947665281523), (56, array([2.2222354 , 3.03312329, 7.58076594]), 1.8895159610570427), (41, array([5.74708999, 1.88247604, 5.61380642]), 1.718230727527205), (35, array([3.01789632, 1.87868872, 4.7738036 ]), 1.4737708442649173), (60, array([3.69471209, 0.58317599, 7.60816599]), 1.4387946272999617)]
# [(37, array([4.25948472, 4.31820832, 5.54648957]), 2.223307903934412), (62, array([4.94965045, 2.98082721, 8.4367196 ]), 2.2160748846196308), (41, array([5.74616777, 1.89258443, 5.62563447]), 1.8531103881846867), (56, array([2.2356666 , 3.02433344, 7.5775594 ]), 1.807964851592216), (35, array([3.06144208, 1.91039263, 4.83837439]), 1.6652278222107832), (60, array([3.71233912, 0.57802838, 7.59094524]), 1.4896642198877046)]
# Processed LiCoO2_1, Index 1
# [(66, array([3.59648312, 2.64772631, 0.91414726]), 3.0560872390065486), (114, array([0.98172295, 4.67200767, 0.59036964]), 2.6067825554070767), (70, array([1.72308091, 3.37975476, 3.52103416]), 2.3966512483564775), (4, array([1.69483657, 6.22431806, 1.50059383]), 0.6731188067296653), (98, array([0.5580994 , 1.45447576, 1.4940421 ]), 1.2689249821600983), (16, array([3.58849463, 3.04868982, 4.03847263]), 0.5128922564350733)]
# Processed g-Li3PO4_9, Index 7
#
# ✅ Results saved to /Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/structure_analysis_M3GNnet_run.csv

# %% [markdown]
# # Evaluate \theta

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# Load CSV files
file2 = "/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/structure_analysis_M3GNnet_run.csv"
file1 = "/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/structure_analysis_interpola.csv"
plot_output_dir = "/Users/achinthyakrishna07/Downloads/migration_barrier/plots/structure_analysis_tight_run_eb_v_interpola.png"  # Replace with actual output directory
output_file = '/Users/achinthyakrishna07/Downloads/MLIP_NEB_outputs/reshma_data/structure_analysis_M3GNnet_run_v_interpola.csv'
# Ensure the output directory exists
os.makedirs(plot_output_dir, exist_ok=True)

df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# Merge the two datasets on Structure and Index
merged_df = df1.merge(df2, on=["Structure", "Index"], suffixes=("_sys1", "_sys2"))

# Compute differences (df2 - df1)
merged_df["Diff_Mean_Dist"] = merged_df["Mean Distance Difference (Å)_sys2"] - merged_df["Mean Distance Difference (Å)_sys1"]
merged_df["Diff_Max_Dist"] = merged_df["Max Distance Difference (Å)_sys2"] - merged_df["Max Distance Difference (Å)_sys1"]
merged_df["Diff_Mean_Solid_Angle"] = merged_df["Mean Solid Angle Difference (sr)_sys2"] - merged_df["Mean Solid Angle Difference (sr)_sys1"]
merged_df["Diff_Max_Solid_Angle"] = merged_df["Max Solid Angle Difference (sr)_sys2"] - merged_df["Max Solid Angle Difference (sr)_sys1"]

# Find the maximum of these differences
merged_df["Max_Diff"] = merged_df[["Diff_Mean_Dist", "Diff_Max_Dist", "Diff_Mean_Solid_Angle", "Diff_Max_Solid_Angle"]].max(axis=1)

# Assign labels
conditions = [
    (merged_df["Max_Diff"] > 0.1),
    (merged_df["Max_Diff"] < 0.01)
]
labels = ["Bad", "Good"]
merged_df["Label"] = np.select(conditions, labels, default="Comparable")

# Save the max difference details to file
max_diff_df = merged_df[["Structure", "Index", "Max_Diff", "Label"]]
max_diff_df.to_csv(output_file, index=False)

# Separate data based on labels
good_data = merged_df[merged_df["Label"] == "Good"]["Index"]
bad_data = merged_df[merged_df["Label"] == "Bad"]["Index"]
comparable_data = merged_df[merged_df["Label"] == "Comparable"]["Index"]

# Plot histograms
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

# Good Histogram
axes[0].hist(good_data, bins=20, color='green', alpha=0.7, edgecolor='black')
axes[0].set_title("Good")
axes[0].set_xlabel("Index")
axes[0].set_ylabel("Frequency")
fig.savefig(os.path.join(plot_output_dir, "histogram_good.png"))

# Bad Histogram
axes[1].hist(bad_data, bins=20, color='red', alpha=0.7, edgecolor='black')
axes[1].set_title("Bad")
axes[1].set_xlabel("Index")
fig.savefig(os.path.join(plot_output_dir, "histogram_bad.png"))

# Comparable Histogram
axes[2].hist(comparable_data, bins=20, color='blue', alpha=0.7, edgecolor='black')
axes[2].set_title("Comparable")
axes[2].set_xlabel("Index")
fig.savefig(os.path.join(plot_output_dir, "histogram_comparable.png"))

# Adjust layout
plt.tight_layout()
plt.show()

# Print total counts
total_counts = merged_df["Label"].value_counts()
print("Total Counts:")
print(total_counts)
# Out:
# Total Counts:
# Label
# Good          51
# Comparable    25
# Bad            1
# Name: count, dtype: int64

# %%
import os
import numpy as np
import itertools
import csv
from pymatgen.core import Structure
from pymatgen.analysis.local_env import VoronoiNN
all_structures_path = {
    'P2S_path2': '/Users/achinthyakrishna07/Downloads/migration_barrier/P2S/path2',
    'P2S_path3': '/Users/achinthyakrishna07/Downloads/migration_barrier/P2S/path3',
    'P2Si_path1': '/Users/achinthyakrishna07/Downloads/migration_barrier/P2Si',
    'PS2_path1': '/Users/achinthyakrishna07/Downloads/migration_barrier/PS2/path1',
    'PS2_path2': '/Users/achinthyakrishna07/Downloads/migration_barrier/PS2/path2',
    'PS2_path3': '/Users/achinthyakrishna07/Downloads/migration_barrier/PS2/path3',
    'PSi2_path1': '/Users/achinthyakrishna07/Downloads/migration_barrier/PSi2/path1',
    'PSi2_path2': '/Users/achinthyakrishna07/Downloads/migration_barrier/PSi2/path2',
    'PSi2_path3': '/Users/achinthyakrishna07/Downloads/migration_barrier/PSi2/path3',
    #'NaV2O4_path1': '/Users/achinthyakrishna07/Downloads/migration_barrier/NaV2O4'
}
def find_nearest_neighbors(structure):
    """Finds the 6 nearest neighbors to the 0th atom in a structure."""
    vnn = VoronoiNN()
    neighbors = vnn.get_nn_info(structure, 0)
    neighbor_list = [(neighbor['site_index'], neighbor['site'].coords, neighbor['poly_info']['solid_angle'])
                     for neighbor in neighbors]
    return sorted(neighbor_list, key=lambda x: structure[0].distance(structure[x[0]]))[:6]

def compute_relevant_distances(structure_file):
    """Computes distances for the 6 nearest neighbors of the 0th atom."""
    structure = Structure.from_file(structure_file)
    nearest_neighbors = find_nearest_neighbors(structure)
    print(nearest_neighbors)
    indices = [index for index, _, _ in nearest_neighbors]
    atom_distances = {(0, index): structure[0].distance(structure[index]) for index in indices}
    pairwise_distances = {(i, j): structure[i].distance(structure[j]) for i, j in itertools.combinations(indices, 2)}
    return {**atom_distances, **pairwise_distances}

def compute_solid_angles(structure_file):
    """Computes the solid angles of Voronoi faces for the 6 nearest neighbors."""
    structure = Structure.from_file(structure_file)
    nearest_neighbors = find_nearest_neighbors(structure)
    return {index: solid_angle for index, _, solid_angle in nearest_neighbors}

def compute_all_differences(structure_file_1, structure_file_2):
    """Computes differences in distances and solid angles between two structures."""
    distances_1, distances_2 = compute_relevant_distances(structure_file_1), compute_relevant_distances(structure_file_2)
    solid_angles_1, solid_angles_2 = compute_solid_angles(structure_file_1), compute_solid_angles(structure_file_2)
    
    distance_differences = [abs(distances_1[p] - distances_2[p]) for p in distances_1 if p in distances_2]
    solid_angle_differences = [abs(solid_angles_1[i] - solid_angles_2[i]) for i in solid_angles_1 if i in solid_angles_2]
    
    return {
        "Mean Distance Difference (Å)": np.mean(distance_differences) if distance_differences else 0,
        "Max Distance Difference (Å)": max(distance_differences) if distance_differences else 0,
        "Mean Solid Angle Difference (sr)": np.mean(solid_angle_differences) if solid_angle_differences else 0,
        "Max Solid Angle Difference (sr)": max(solid_angle_differences) if solid_angle_differences else 0
    }

# CSV Output File
output_csv = "/Users/achinthyakrishna07/Downloads/structure_idpp_v_DFT.csv"

with open(output_csv, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Structure", "Index", "Mean Distance Difference (Å)", "Max Distance Difference (Å)","Mean Solid Angle Difference (sr)", "Max Solid Angle Difference (sr)"])  # "Mean Solid Angle Difference (sr)", "Max Solid Angle Difference (sr)"])
    
    for structure_name, base_path in all_structures_path.items():
        for j in range(1, 8):
            dft_structure_path = os.path.join(base_path, f"DFT_NEB_structures/{j}/CONTCAR.vasp")
            mace_structure_path = os.path.join(base_path, f"idpp_experiment/image_{j}.vasp")
            
            if os.path.exists(dft_structure_path) and os.path.exists(mace_structure_path):
                results = compute_all_differences(dft_structure_path, mace_structure_path)
                writer.writerow([structure_name, j, results["Mean Distance Difference (Å)"], results["Max Distance Difference (Å)"],
                                 results["Mean Solid Angle Difference (sr)"], results["Max Solid Angle Difference (sr)"]])
                print(f"Processed {structure_name}, Index {j}")
            else:
                print(f"Skipping {structure_name}, Index {j} (Missing Files)")

print(f"\n✅ Results saved to {output_csv}")
# Out:
# [(19, array([10.49766727,  5.1884479 ,  5.6349002 ]), 2.1055578862834476), (16, array([8.15067771, 2.85663105, 3.1001329 ]), 2.0197515984000884), (14, array([6.63007166, 4.82092188, 4.34454541]), 2.0239439300437407), (15, array([11.13421731,  5.39407797,  2.99328619]), 1.808963733313298), (17, array([9.62001321, 7.40755032, 4.1029329 ]), 1.487353690103067), (18, array([7.53316679, 5.08060343, 1.68052824]), 1.2559470938168793)]
# [(16, array([7.99512299, 3.02937844, 3.23206612]), 2.326772182579875), (14, array([6.36353047, 4.94315316, 4.40537751]), 2.2970723786080995), (19, array([10.07198094,  5.39844775,  5.74746968]), 2.1319316376625914), (18, array([7.38632895, 5.26574979, 1.84528332]), 1.4527578462435564), (15, array([10.88457539,  5.68621138,  3.14433688]), 1.4741419044748199), (17, array([9.26749052, 7.55677569, 4.18783436]), 1.3350093862702166)]
# Processed P2S_path2, Index 1
# [(19, array([10.61325157,  5.18107464,  5.66222866]), 2.093183508749605), (16, array([8.11907108, 2.82610699, 3.03039241]), 2.0634074193299106), (14, array([6.64941643, 4.80873195, 4.36274489]), 2.1635352421160943), (32, array([8.81449604, 4.18156008, 6.99171888]), 1.5772083004977662), (35, array([9.73178008, 1.75065665, 4.48972729]), 1.385289416032728), (15, array([11.17284648,  5.37673935,  3.00098583]), 1.3969796316451029)]
# [(33, array([9.11251195, 6.23798581, 0.18174996]), 1.9608705169695517), (17, array([9.67622507, 7.66172662, 4.16926876]), 1.7473303290900228), (15, array([11.18668944,  5.54684821,  3.03759065]), 1.72679117788351), (25, array([10.90817441,  8.26045079, -0.2133199 ]), 1.532352580085613), (23, array([11.83061838,  5.98734663,  0.68574454]), 1.2903973929117223), (34, array([7.91586011, 8.54018601, 2.75737396]), 1.2782261674182824)]
# [(17, array([9.45617796, 7.31391767, 4.10759103]), 2.083577585807104), (15, array([11.00452311,  5.31298044,  3.09939921]), 1.8105806919395917), (33, array([8.93402629, 6.15280858, 0.10913825]), 1.7344237676908878), (23, array([11.6522486 ,  5.71073037,  0.68135705]), 1.2045997667697077), (25, array([10.78377158,  8.08689599, -0.28315984]), 1.194393781795113), (13, array([8.59875595, 8.56441455, 3.91231174]), 0.275945562966535)]
# Processed PSi2_path3, Index 7
#
# ✅ Results saved to /Users/achinthyakrishna07/Downloads/structure_idpp_v_DFT.csv

# %%
import os
import numpy as np
import itertools
from pymatgen.core import Structure
from pymatgen.analysis.local_env import VoronoiNN

# Define structure paths
all_structures_path = {
    'CoF3_Co': '/Users/achinthyakrishna07/Downloads/dereje_data/Perovskites/Co/CoF3',
    'Ca0.5MnF3': '/Users/achinthyakrishna07/Downloads/dereje_data/Perovskites/Mn/Ca0.5MnF3',
    'Ca0.5NiF3': '/Users/achinthyakrishna07/Downloads/dereje_data/Perovskites/Ni/Ca0.5NiF3',
    'NiF3': '/Users/achinthyakrishna07/Downloads/dereje_data/Perovskites/Ni/NiF3',
}

def find_nearest_neighbors(structure):
    """Finds the 6 nearest neighbors to the 0th atom in a structure."""
    vnn = VoronoiNN()
    neighbors = vnn.get_nn_info(structure, 0)
    neighbor_list = [(neighbor['site_index'], neighbor['site'].coords, neighbor['poly_info']['solid_angle'])
                     for neighbor in neighbors]
    return sorted(neighbor_list, key=lambda x: structure[0].distance(structure[x[0]]))[:6]

def display_nearest_neighbors(dft_file, mace_file):
    """Displays nearest neighbors' site indices, coordinates, and solid angles for DFT and MACE structures."""
    structure_dft = Structure.from_file(dft_file)
    structure_mace = Structure.from_file(mace_file)
    
    nearest_neighbors_dft = find_nearest_neighbors(structure_dft)
    nearest_neighbors_mace = find_nearest_neighbors(structure_mace)
    
    print(f"\nNearest neighbors for {dft_file} (DFT):")
    for index, coords, solid_angle in nearest_neighbors_dft:
        print(f"Index: {index}, Coordinates: {coords}, Solid Angle: {solid_angle}")
    
    print(f"\nNearest neighbors for {mace_file} (MACE):")
    for index, coords, solid_angle in nearest_neighbors_mace:
        print(f"Index: {index}, Coordinates: {coords}, Solid Angle: {solid_angle}")

# Process structures
for structure_name, base_path in all_structures_path.items():
    for j in range(1, 8):
        dft_structure_path = os.path.join(base_path, f"0{j}/CONTCAR")
        mace_structure_path = os.path.join(base_path, f"idpp_tight_run_eb/neb_optimized_{j}.vasp")
        
        if os.path.exists(dft_structure_path) and os.path.exists(mace_structure_path):
            display_nearest_neighbors(dft_structure_path, mace_structure_path)
        else:
            print(f"Skipping {structure_name}, Index {j} (Missing DFT or MACE File)")
# Out:
# Nearest neighbors for /Users/achinthyakrishna07/Downloads/dereje_data/Perovskites/
# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load CSV files
file2 = "/Users/achinthyakrishna07/Downloads/structure_analysis_idpp_tight_eb.csv"  # Replace with actual path
file1 = "/Users/achinthyakrishna07/Downloads/structure_idpp_v_DFT.csv"  # Replace with actual path
output_file = "/Users/achinthyakrishna07/Downloads/idpp_v_mace.csv"  # Replace with actual output file path

df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# Merge the two datasets on Structure and Index
merged_df = df1.merge(df2, on=["Structure", "Index"], suffixes=("_sys1", "_sys2"))

# Compute differences (df2 - df1)
merged_df["Diff_Mean_Dist"] = merged_df["Mean Distance Difference (Å)_sys2"] - merged_df["Mean Distance Difference (Å)_sys1"]
merged_df["Diff_Max_Dist"] = merged_df["Max Distance Difference (Å)_sys2"] - merged_df["Max Distance Difference (Å)_sys1"]
merged_df["Diff_Mean_Solid_Angle"] = merged_df["Mean Solid Angle Difference (sr)_sys2"] - merged_df["Mean Solid Angle Difference (sr)_sys1"]
merged_df["Diff_Max_Solid_Angle"] = merged_df["Max Solid Angle Difference (sr)_sys2"] - merged_df["Max Solid Angle Difference (sr)_sys1"]

# Find the maximum of these differences
merged_df["Max_Diff"] = merged_df[["Diff_Mean_Dist", "Diff_Max_Dist", "Diff_Mean_Solid_Angle", "Diff_Max_Solid_Angle"]].max(axis=1)

# Assign labels
conditions = [
    (merged_df["Max_Diff"] > 0.1),
    (merged_df["Max_Diff"] < 0.01)
]
labels = ["Bad", "Good"]
merged_df["Label"] = np.select(conditions, labels, default="Comparable")

# Save the max difference details to file
max_diff_df = merged_df[["Structure", "Index", "Max_Diff", "Label"]]
max_diff_df.to_csv(output_file, index=False)

# Separate data based on labels
good_data = merged_df[merged_df["Label"] == "Good"]["Index"]
bad_data = merged_df[merged_df["Label"] == "Bad"]["Index"]
comparable_data = merged_df[merged_df["Label"] == "Comparable"]["Index"]

# Plot histograms
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

# Good Histogram
axes[0].hist(good_data, bins=20, color='green', alpha=0.7, edgecolor='black')
axes[0].set_title("Good")
axes[0].set_xlabel("Index")
axes[0].set_ylabel("Frequency")

# Bad Histogram
axes[1].hist(bad_data, bins=20, color='red', alpha=0.7, edgecolor='black')
axes[1].set_title("Bad")
axes[1].set_xlabel("Index")

# Comparable Histogram
axes[2].hist(comparable_data, bins=20, color='blue', alpha=0.7, edgecolor='black')
axes[2].set_title("Comparable")
axes[2].set_xlabel("Index")

# Adjust layout
plt.tight_layout()
plt.show()

# Print total counts
total_counts = merged_df["Label"].value_counts()
print("Total Counts:")
print(total_counts)
# Out:
# Total Counts:
# Label
# Good          40
# Comparable    15
# Bad            8
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load CSV files
file2 = "/Users/achinthyakrishna07/Downloads/structure_analysis_tight_tangent.csv"  # Replace with actual path
file1 = "/Users/achinthyakrishna07/Downloads/structure_analysis_results_std_lose.csv"  # Replace with actual path
output_file = "/Users/achinthyakrishna07/Downloads/tight_tan_v_std_lose.csv"  # Replace with actual output file path

df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# Merge the two datasets on Structure and Index
merged_df = df1.merge(df2, on=["Structure", "Index"], suffixes=("_sys1", "_sys2"))

# Compute differences (df2 - df1)
merged_df["Diff_Mean_Dist"] = merged_df["Mean Distance Difference (Å)_sys2"] - merged_df["Mean Distance Difference (Å)_sys1"]
merged_df["Diff_Max_Dist"] = merged_df["Max Distance Difference (Å)_sys2"] - merged_df["Max Distance Difference (Å)_sys1"]
merged_df["Diff_Mean_Solid_Angle"] = merged_df["Mean Solid Angle Difference (sr)_sys2"] - merged_df["Mean Solid Angle Difference (sr)_sys1"]
merged_df["Diff_Max_Solid_Angle"] = merged_df["Max Solid Angle Difference (sr)_sys2"] - merged_df["Max Solid Angle Difference (sr)_sys1"]

# Find the maximum of these differences
merged_df["Max_Diff"] = merged_df[["Diff_Mean_Dist", "Diff_Max_Dist", "Diff_Mean_Solid_Angle", "Diff_Max_Solid_Angle"]].max(axis=1)

# Assign labels
conditions = [
    (merged_df["Max_Diff"] > 0.1),
    (merged_df["Max_Diff"] < 0.01)
]
labels = ["Bad", "Good"]
merged_df["Label"] = np.select(conditions, labels, default="Comparable")

# Save the max difference details to file
max_diff_df = merged_df[["Structure", "Index", "Max_Diff", "Label"]]
max_diff_df.to_csv(output_file, index=False)

# Separate data based on labels
good_data = merged_df[merged_df["Label"] == "Good"]["Index"]
bad_data = merged_df[merged_df["Label"] == "Bad"]["Index"]
comparable_data = merged_df[merged_df["Label"] == "Comparable"]["Index"]

# Plot histograms
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

# Good Histogram
axes[0].hist(good_data, bins=20, color='green', alpha=0.7, edgecolor='black')
axes[0].set_title("Good")
axes[0].set_xlabel("Index")
axes[0].set_ylabel("Frequency")

# Bad Histogram
axes[1].hist(bad_data, bins=20, color='red', alpha=0.7, edgecolor='black')
axes[1].set_title("Bad")
axes[1].set_xlabel("Index")

# Comparable Histogram
axes[2].hist(comparable_data, bins=20, color='blue', alpha=0.7, edgecolor='black')
axes[2].set_title("Comparable")
axes[2].set_xlabel("Index")

# Adjust layout
plt.tight_layout()
plt.show()

# Print total counts
total_counts = merged_df["Label"].value_counts()
print("Total Counts:")
print(total_counts)
# Out:
# Total Counts:
# Label
# Good          39
# Comparable    15
# Bad            9
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load CSV files
file2 = "/Users/achinthyakrishna07/Downloads/structure_analysis_tight_eb.csv"  # Replace with actual path
file1 = "/Users/achinthyakrishna07/Downloads/structure_analysis_interpola.csv"  # Replace with actual path
output_file = "/Users/achinthyakrishna07/Downloads/tight_eb_v_interpola.csv"  # Replace with actual output file path

df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# Merge the two datasets on Structure and Index
merged_df = df1.merge(df2, on=["Structure", "Index"], suffixes=("_sys1", "_sys2"))

# Compute differences (df2 - df1)
merged_df["Diff_Mean_Dist"] = merged_df["Mean Distance Difference (Å)_sys2"] - merged_df["Mean Distance Difference (Å)_sys1"]
merged_df["Diff_Max_Dist"] = merged_df["Max Distance Difference (Å)_sys2"] - merged_df["Max Distance Difference (Å)_sys1"]
merged_df["Diff_Mean_Solid_Angle"] = merged_df["Mean Solid Angle Difference (sr)_sys2"] - merged_df["Mean Solid Angle Difference (sr)_sys1"]
merged_df["Diff_Max_Solid_Angle"] = merged_df["Max Solid Angle Difference (sr)_sys2"] - merged_df["Max Solid Angle Difference (sr)_sys1"]

# Find the maximum of these differences
merged_df["Max_Diff"] = merged_df[["Diff_Mean_Dist", "Diff_Max_Dist", "Diff_Mean_Solid_Angle", "Diff_Max_Solid_Angle"]].max(axis=1)

# Assign labels
conditions = [
    (merged_df["Max_Diff"] > 0.1),
    (merged_df["Max_Diff"] < 0.01)
]
labels = ["Bad", "Good"]
merged_df["Label"] = np.select(conditions, labels, default="Comparable")

# Save the max difference details to file
max_diff_df = merged_df[["Structure", "Index", "Max_Diff", "Label"]]
max_diff_df.to_csv(output_file, index=False)

# Separate data based on labels
good_data = merged_df[merged_df["Label"] == "Good"]["Index"]
bad_data = merged_df[merged_df["Label"] == "Bad"]["Index"]
comparable_data = merged_df[merged_df["Label"] == "Comparable"]["Index"]

# Plot histograms
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

# Good Histogram
axes[0].hist(good_data, bins=20, color='green', alpha=0.7, edgecolor='black')
axes[0].set_title("Good")
axes[0].set_xlabel("Index")
axes[0].set_ylabel("Frequency")

# Bad Histogram
axes[1].hist(bad_data, bins=20, color='red', alpha=0.7, edgecolor='black')
axes[1].set_title("Bad")
axes[1].set_xlabel("Index")

# Comparable Histogram
axes[2].hist(comparable_data, bins=20, color='blue', alpha=0.7, edgecolor='black')
axes[2].set_title("Comparable")
axes[2].set_xlabel("Index")

# Adjust layout
plt.tight_layout()
plt.show()

# Print total counts
total_counts = merged_df["Label"].value_counts()
print("Total Counts:")
print(total_counts)
# Out:
# Total Counts:
# Label
# Good          52
# Comparable     6
# Bad            5
# Name: count, dtype: int64

# %%
import os
import numpy as np
import csv
from pymatgen.core import Structure

# Define all structure paths
#all_structures_path = {
 #   'P2S_path2': '/Users/achinthyakrishna07/Downloads/migration_barrier/P2S/path2',
  #  'P2S_path3': '/Users/achinthyakrishna07/Downloads/migration_barrier/P2S/path3',
   #'PS2_path1': '/Users/achinthyakrishna07/Downloads/migration_barrier/PS2/path1',
   # 'PS2_path2': '/Users/achinthyakrishna07/Downloads/migration_barrier/PS2/path2',
    #'PS2_path3': '/Users/achinthyakrishna07/Downloads/migration_barrier/PS2/path3',
    #'PSi2_path1': '/Users/achinthyakrishna07/Downloads/migration_barrier/PSi2/path1',
    #'PSi2_path2': '/Users/achinthyakrishna07/Downloads/migration_barrier/PSi2/path2',
    #'PSi2_path3': '/Users/achinthyakrishna07/Downloads/migration_barrier/PSi2/path3',
#}
all_structures_path = {
    'test': '/Users/achinthyakrishna07/Downloads/migration_barrier/P2Si'
}
def compute_cartesian_difference(structure_file_1, structure_file_2):
    """Computes Cartesian coordinate difference of the 0th species between two structures."""
    structure_1 = Structure.from_file(structure_file_1)
    structure_2 = Structure.from_file(structure_file_2)
    
    coords_1 = np.array(structure_1[0].coords)
    coords_2 = np.array(structure_2[0].coords)
    
    difference = np.linalg.norm(coords_1 - coords_2)
    
    return difference

# CSV Output File
output_csv = "/Users/achinthyakrishna07/Downloads/ca_diff_test.csv"

# Open CSV file and write headers before looping through structures
with open(output_csv, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Structure", "Index", "Cartesian Difference (Å)"])

    # Loop through all structures and indices (j=1 to 8)
    for structure_name, base_path in all_structures_path.items():
        for j in range(1, 8):  # j goes from 1 to 8
            dft_structure_path = os.path.join(base_path, f"DFT_NEB_structures/{j}/CONTCAR.vasp")
            mace_structure_path = os.path.join(base_path, f"tight_tangent/neb_test_{j}.vasp")

            if os.path.exists(dft_structure_path) and os.path.exists(mace_structure_path):
                difference = compute_cartesian_difference(dft_structure_path, mace_structure_path)
                writer.writerow([structure_name, j, difference])
                print(f"Processed {structure_name}, Index {j}")
            else:
                print(f"Skipping {structure_name}, Index {j} (Missing Files)")

print(f"\n✅ Results saved to {output_csv}")
# Out:
# Processed test, Index 1
# Processed test, Index 2
# Processed test, Index 3
# Processed test, Index 4
# Processed test, Index 5
# Processed test, Index 6
# Processed test, Index 7
#
# ✅ Results saved to /Users/achinthyakrishna07/Downloads/ca_diff_test.csv

# %%
## import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
file_path = "/Users/achinthyakrishna07/Downloads/Mace_tight_run _Ca_posn_comparison.csv"
df = pd.read_csv(file_path)

# Rename columns properly
df.columns = [
    "Structure", "Index", "Cartesian Difference (Å)", "0.1,std", "5,tangent",
    "5,eb", "2.5,std", "2.5,tangent", "2.5,eb", "0.1,tangent", "0.1,eb", "Duplicate"
]

# Drop the first row, which contained misaligned headers
df = df.iloc[1:].reset_index(drop=True)

# Convert numeric columns to float
numeric_cols = df.columns[2:-1]  # Excluding Structure and Duplicate column
df[numeric_cols] = df[numeric_cols].astype(float)

# Compute how often "Cartesian Difference (Å)" is NOT the minimum
count_not_min = {}
for col in numeric_cols[1:]:  # Exclude "Cartesian Difference (Å)"
    count_not_min[col] = (df["Cartesian Difference (Å)"] > df[col]).sum()

# Print number of cases where "Cartesian Difference (Å)" is not the minimum
print("Number of cases where 'Cartesian Difference (Å)' is NOT the minimum:")
for method, count in count_not_min.items():
    print(f"{method}: {count}")

# Identify which index had the minimum value most frequently
df["Min Method"] = df[numeric_cols].idxmin(axis=1)
index_counts = df["Index"].astype(int).value_counts().sort_index()

# Plot Histogram
plt.figure(figsize=(8, 5))
plt.bar(index_counts.index, index_counts.values, color='skyblue', edgecolor='black')

plt.xlabel("Index")
plt.ylabel("Frequency (Number of Cases with Minimum Value)")
plt.title("Frequency Distribution of Minimum Values per Index")
plt.xticks(range(1, 8))  # Ensure x-axis has indices 1 to 7
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show plot
plt.show()
# Out:
# Number of cases where 'Cartesian Difference (Å)' is NOT the minimum:
# 0.1,std: 40
# 5,tangent: 39
# 5,eb: 39
# 2.5,std: 25
# 2.5,tangent: 36
# 2.5,eb: 39
# 0.1,tangent: 31
# 0.1,eb: 29
